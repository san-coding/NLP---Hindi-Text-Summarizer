# %% [markdown]
# TOPIC : Text Summarization
#
# Corpus Language : Telugu
#
# No.of Team Members : 4

# %%
import nltk
from nltk.corpus import stopwords 
import string
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
import re

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Indic NLP Library

# %%
pip install indic-nlp-library

# %% [markdown]
# # making all corpus into one file

# %%
with open('/content/ts1.txt') as fp:
	data = fp.read()

with open('/content/ts2.txt') as fp:
	data2 = fp.read()

with open('/content/ts3.txt') as fp:
	data3 = fp.read()
 
with open('/content/ts4.txt') as fp:
	data4 = fp.read()


data += "\n"
data += data2
data += "\n"
data += data3
data += "\n"
data += data4
hindi_corpus = data 
print(hindi_corpus)
print(len(hindi_corpus))
# Out:
# मेरे मित्र रोहित का जन्म-दिन था। उसने अन्य मित्रों के साथ मुझे भी बुलाया। रोहित के कुछ रिश्तेदार भी आए हुए थे, किन्तु अधिकतर मित्र ही उपस्थित थे। घर के आँगन में ही समारोह का आयोजन किया गया था। उस स्थान को बहुत ही सुंदर ढंग से सजाया गया था। हर जगह झण्डियाँ और गुब्बारे थे। आँगन में लगे एक पेड़ पर रंग-बिरंगे बल्ब जगमग कर रहे थे। जब मैं पहुँचा तो मेहमान आने शुरू ही हुए थे। मेहमान रोहित के लिए कोई-न-कोई उपहार लेकर आते, उसके निकट जाकर बधाई देते और रोहित उनका धन्यवाद करता। क्रमशः लोग छोटी-छोटी टोलियों में बैठकर गपशप करने लगे। संगीत की मधुर ध्वनियाँ गूँज रही थी। एक-दो मित्र उठकर नृत्य करने लगे। कुछ मित्र तालियों बजा कर अपना योगदान देने लगे। चारों ओर उल्लास का वातावरण था। सात बजे के लगभग केक काटा गया। सब मित्रों ने तालियाँ बजाई और मिलकर जन्मदिन की बधाई का गीत गाया। माँ ने रोहित को केक खिलाया। अन्य लोगों ने भी केक खाया। फिर सभी खाना खाने लगे। खाने में अनेक प्रकार की मिठाइयाँ और नमकीन थे। तब हमने रोहित को एक बार फिर बधाई दी, उसकी दीर्घायु की कामना की और अपने-अपने घर को चल दिए। वह कार्यक्रम इतना
# ...

# %% [markdown]
# # sentence tokenization

# %%
from indicnlp.tokenize import sentence_tokenize
sentences=sentence_tokenize.sentence_split(hindi_corpus, lang='hi')

for t in sentences:
    print(t)
# Out:
# मेरे मित्र रोहित का जन्म-दिन था।
# उसने अन्य मित्रों के साथ मुझे भी बुलाया।
# रोहित के कुछ रिश्तेदार भी आए हुए थे, किन्तु अधिकतर मित्र ही उपस्थित थे।
# घर के आँगन में ही समारोह का आयोजन किया गया था।
# उस स्थान को बहुत ही सुंदर ढंग से सजाया गया था।
# हर जगह झण्डियाँ और गुब्बारे थे।
# आँगन में लगे एक पेड़ पर रंग-बिरंगे बल्ब जगमग कर रहे थे।
# जब मैं पहुँचा तो मेहमान आने शुरू ही हुए थे।
# मेहमान रोहित के लिए कोई-न-कोई उपहार लेकर आते, उसके निकट जाकर बधाई देते और रोहित उनका धन्यवाद करता।
# क्रमशः लोग छोटी-छोटी टोलियों में बैठकर गपशप करने लगे।
# संगीत की मधुर ध्वनियाँ गूँज रही थी।
# एक-दो मित्र उठकर नृत्य करने लगे।
# कुछ मित्र तालियों बजा कर अपना योगदान देने लगे।
# चारों ओर उल्लास का वातावरण था।
# सात बजे के लगभग केक काटा गया।
# सब मित्रों ने तालियाँ बजाई और मिलकर जन्मदिन की बधाई का गीत गाया।
# माँ ने रोहित को केक खिलाया।
# अन्य लोगों ने भी केक खाया।
# फिर सभी खाना खाने लगे।
# खाने में अनेक प्रकार की मिठाइयाँ और नमकीन थे।
# ...

# %% [markdown]
# # Removing number and punctuation

# %%
import re
import string

def remove_punctuation (text):
  remove_numbers = re.sub(r'\d+','',hindi_corpus)
  tran_te_data1 = remove_numbers.translate(t)
  translator = str.maketrans( '', '', string.punctuation)
  translator = str.maketrans( '“', ' ', string.punctuation)
  return text. translate(translator)
tran_hi_data = remove_punctuation(hindi_corpus)
print(remove_punctuation(hindi_corpus))
# Out:
# मेरे मित्र रोहित का जन्मदिन था। उसने अन्य मित्रों के साथ मुझे भी बुलाया। रोहित के कुछ रिश्तेदार भी आए हुए थे किन्तु अधिकतर मित्र ही उपस्थित थे। घर के आँगन में ही समारोह का आयोजन किया गया था। उस स्थान को बहुत ही सुंदर ढंग से सजाया गया था। हर जगह झण्डियाँ और गुब्बारे थे। आँगन में लगे एक पेड़ पर रंगबिरंगे बल्ब जगमग कर रहे थे। जब मैं पहुँचा तो मेहमान आने शुरू ही हुए थे। मेहमान रोहित के लिए कोईनकोई उपहार लेकर आते उसके निकट जाकर बधाई देते और रोहित उनका धन्यवाद करता। क्रमशः लोग छोटीछोटी टोलियों में बैठकर गपशप करने लगे। संगीत की मधुर ध्वनियाँ गूँज रही थी। एकदो मित्र उठकर नृत्य करने लगे। कुछ मित्र तालियों बजा कर अपना योगदान देने लगे। चारों ओर उल्लास का वातावरण था। सात बजे के लगभग केक काटा गया। सब मित्रों ने तालियाँ बजाई और मिलकर जन्मदिन की बधाई का गीत गाया। माँ ने रोहित को केक खिलाया। अन्य लोगों ने भी केक खाया। फिर सभी खाना खाने लगे। खाने में अनेक प्रकार की मिठाइयाँ और नमकीन थे। तब हमने रोहित को एक बार फिर बधाई दी उसकी दीर्घायु की कामना की और अपनेअपने घर को चल दिए। वह कार्यक्रम इतना अच्छा था 
# ...

# %% [markdown]
# # Word tokenization

# %%
from indicnlp.tokenize import indic_tokenize  
print('Hindi word tokenzation: ')
for hin_word in indic_tokenize.trivial_tokenize(tran_hi_data): 
    print(hin_word)
# Out:
# Hindi word tokenzation:
# मेरे
# मित्र
# रोहित
# का
# जन्मदिन
# था
# ।
# उसने
# अन्य
# मित्रों
# के
# साथ
# मुझे
# भी
# बुलाया
# ।
# रोहित
# के
# कुछ
# रिश्तेदार
# भी
# आए
# हुए
# थे
# किन्तु
# अधिकतर
# मित्र
# ही
# उपस्थित
# थे
# ।
# घर
# के
# आँगन
# में
# ही
# समारोह
# का
# आयोजन
# किया
# गया
# था
# ।
# उस
# स्थान
# को
# बहुत
# ही
# सुंदर
# ढंग
# से
# सजाया
# गया
# था
# ।
# हर
# जगह
# झण्डियाँ
# और
# गुब्बारे
# थे
# ।
# आँगन
# में
# लगे
# एक
# पेड़
# पर
# रंगबिरंगे
# बल्ब
# जगमग
# कर
# रहे
# थे
# ।
# जब
# मैं
# पहुँचा
# तो
# मेहमान
# आने
# शुरू
# ही
# हुए
# थे
# ।
# मेहमान
# रोहित
# के
# लिए
# कोईनकोई
# उपहार
# लेकर
# आते
# उसके
# निकट
# जाकर
# बधाई
# देते
# और
# रोहित
# उनका
# धन्यवाद
# करता
# ।
# क्रमशः
# लोग
# छोटीछोटी
# टोलियों
# में
# बैठकर
# गपशप
# करने
# लगे
# ।
# संगीत
# की
# मधुर
# ध्वनियाँ
# गूँज
# रही
# थी
# ।
# एकदो
# मित्र
# उठकर
# नृत्य
# करने
# लगे
# ।
# कुछ
# मित्र
# तालियों
# बजा
# कर
# अपना
# योगदान
# देने
# लगे
# ।
# चारों
# ओर
# उल्लास
# का
# वातावरण
# था
# ।
# ...

# %% [markdown]
# # Stemming with porterStemmer

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
ps = PorterStemmer()
for ts in tran_hi_data:
  print(ts, ':', ps.stem(ts))
# Out:
# म : म
# े : े
# र : र
# े : े
#   :
# म : म
# ि : ि
# त : त
# ् : ्
# र : र
#   :
# र : र
# ो : ो
# ह : ह
# ि : ि
# त : त
#   :
# क : क
# ा : ा
#   :
# ज : ज
# न : न
# ् : ्
# म : म
# द : द
# ि : ि
# न : न
#   :
# थ : थ
# ा : ा
# । : ।
#   :
# उ : उ
# स : स
# न : न
# े : े
#   :
# अ : अ
# न : न
# ् : ्
# य : य
#   :
# म : म
# ि : ि
# त : त
# ् : ्
# र : र
# ो : ो
# ं : ं
#   :
# क : क
# े : े
#   :
# स : स
# ा : ा
# थ : थ
#   :
# म : म
# ु : ु
# झ : झ
# े : े
#   :
# भ : भ
# ी : ी
#   :
# ब : ब
# ु : ु
# ल : ल
# ा : ा
# य : य
# ा : ा
# । : ।
#   :
# र : र
# ो : ो
# ह : ह
# ि : ि
# त : त
#   :
# क : क
# े : े
#   :
# क : क
# ु : ु
# छ : छ
#   :
# र : र
# ि : ि
# श : श
# ् : ्
# त : त
# े : े
# द : द
# ा : ा
# र : र
#   :
# भ : भ
# ी : ी
#   :
# आ : आ
# ए : ए
#   :
# ह : ह
# ु : ु
# ए : ए
#   :
# थ : थ
# े : े
#   :
# क : क
# ि : ि
# न : न
# ् : ्
# त : त
# ु : ु
#   :
# अ : अ
# ध : ध
# ि : ि
# क : क
# त : त
# र : र
#   :
# म : म
# ि : ि
# त : त
# ् : ्
# र : र
#   :
# ह : ह
# ी : ी
# ...

# %% [markdown]
# # Lemmatization

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()
def lemetize(text):
    word_tokens = word_tokenize(text)
    filtered_word = [lem.lemmatize(word) for word in word_tokens]
    filtered_word = " ".join(filtered_word)
    return filtered_word
lemetize(tran_hi_data)
# Out:
# 'मेरे मित्र रोहित का जन्मदिन था। उसने अन्य मित्रों के साथ मुझे भी बुलाया। रोहित के कुछ रिश्तेदार भी आए हुए थे किन्तु अधिकतर मित्र ही उपस्थित थे। घर के आँगन में ही समारोह का आयोजन किया गया था। उस स्थान को बहुत ही सुंदर ढंग से सजाया गया था। हर जगह झण्डियाँ और गुब्बारे थे। आँगन में लगे एक पेड़ पर रंगबिरंगे बल्ब जगमग कर रहे थे। जब मैं पहुँचा तो मेहमान आने शुरू ही हुए थे। मेहमान रोहित के लिए कोईनकोई उपहार लेकर आते उसके निकट जाकर बधाई देते और रोहित उनका धन्यवाद करता। क्रमशः लोग छोटीछोटी टोलियों में बैठकर गपशप करने लगे। संगीत की मधुर ध्वनियाँ गूँज रही थी। एकदो मित्र उठकर नृत्य करने लगे। कुछ मित्र तालियों बजा कर अपना योगदान देने लगे। चारों ओर उल्लास का वातावरण था। सात बजे के लगभग केक काटा गया। सब मित्रों ने तालियाँ बजाई और मिलकर जन्मदिन की बधाई का गीत गाया। माँ ने रोहित को केक खिलाया। अन्य लोगों ने भी केक खाया। फिर सभी खाना खाने लगे। खाने में अनेक प्रकार की मिठाइयाँ और नमकीन थे। तब हमने रोहित को एक बार फिर बधाई दी उसकी दीर्घायु की कामना की और अपनेअपने घर को चल दिए। वह कार्यक्रम इतना अच्छा था
# ...

# %%
print(len(tran_hi_data))
# Out:
# 4675

# %% [markdown]
# # Removing stopwords with file

# %%
#stopwords
with open('/content/hindi-stopwords.txt') as fp:
	stopwords = fp.read()
print(stopwords)
# Out:
# पर
# इन
# वह
# यिह
# वुह
# जिन्हें
# जिन्हों
# तिन्हें
# तिन्हों
# किन्हों
# किन्हें
# इत्यादि
# द्वारा
# इन्हें
# इन्हों
# उन्हों
# बिलकुल
# निहायत
# ऱ्वासा
# इन्हीं
# उन्हीं
# उन्हें
# इसमें
# जितना
# दुसरा
# कितना
# दबारा
# साबुत
# वग़ैरह
# दूसरे
# कौनसा
# लेकिन
# होता
# करने
# किया
# लिये
# अपने
# नहीं
# दिया
# इसका
# करना
# वाले
# सकते
# इसके
# सबसे
# होने
# करते
# बहुत
# वर्ग
# करें
# होती
# अपनी
# उनके
# कहते
# होते
# करता
# उनकी
# इसकी
# सकता
# रखें
# अपना
# उसके
# जिसे
# तिसे
# किसे
# किसी
# काफ़ी
# पहले
# नीचे
# बाला
# यहाँ
# जैसा
# जैसे
# मानो
# अंदर
# भीतर
# पूरा
# सारा
# होना
# उनको
# वहाँ
# वहीं
# जहाँ
# जीधर
# उनका
# इनका
# ﻿के
# हैं
# गया
# बनी
# एवं
# हुआ
# साथ
# बाद
# लिए
# कुछ
# कहा
# यदि
# हुई
# इसे
# हुए
# अभी
# सभी
# कुल
# रहा
# रहे
# इसी
# उसे
# जिस
# जिन
# तिस
# तिन
# कौन
# किस
# कोई
# ऐसे
# तरह
# किर
# साभ
# संग
# यही
# बही
# उसी
# फिर
# मगर
# का
# एक
# यह
# से
# को
# इस
# कि
# जो
# कर
# मे
# ने
# तो
# ही
# या
# हो
# था
# तक
# आप
# ये
# थे
# दो
# वे
# थी
# जा
# ...

# %%
#removing Stopwords
words = word_tokenize(tran_hi_data)
filtered_sentence = []
for w in words:
  if w not in stopwords:
    filtered_sentence.append(w)
final_list= filtered_sentence
print(filtered_sentence)
print(len(filtered_sentence))
# Out:
# ['मेरे', 'मित्र', 'रोहित', 'जन्मदिन', 'था।', 'उसने', 'अन्य', 'मित्रों', 'मुझे', 'बुलाया।', 'रोहित', 'रिश्तेदार', 'आए', 'किन्तु', 'अधिकतर', 'मित्र', 'उपस्थित', 'थे।', 'आँगन', 'समारोह', 'आयोजन', 'था।', 'स्थान', 'सुंदर', 'ढंग', 'सजाया', 'था।', 'हर', 'जगह', 'झण्डियाँ', 'गुब्बारे', 'थे।', 'आँगन', 'लगे', 'पेड़', 'रंगबिरंगे', 'बल्ब', 'जगमग', 'थे।', 'मैं', 'पहुँचा', 'मेहमान', 'आने', 'शुरू', 'थे।', 'मेहमान', 'रोहित', 'कोईनकोई', 'उपहार', 'लेकर', 'आते', 'निकट', 'जाकर', 'बधाई', 'देते', 'रोहित', 'धन्यवाद', 'करता।', 'क्रमशः', 'लोग', 'छोटीछोटी', 'टोलियों', 'बैठकर', 'गपशप', 'लगे।', 'संगीत', 'मधुर', 'ध्वनियाँ', 'गूँज', 'रही', 'थी।', 'एकदो', 'मित्र', 'उठकर', 'नृत्य', 'लगे।', 'मित्र', 'तालियों', 'बजा', 'योगदान', 'देने', 'लगे।', 'चारों', 'ओर', 'उल्लास', 'वातावरण', 'था।', 'सात', 'बजे', 'लगभग', 'केक', 'काटा', 'गया।', 'मित्रों', 'तालियाँ', 'बजाई', 'मिलकर', 'जन्मदिन', 'बधाई', 'गीत', 'गाया।', 'माँ', 'रोहित', 'केक', 'खिलाया।', 'अन्य', 'लोगों', 'केक', 'खाया।', 'खाना', 'खाने', 'लगे।', 'खाने', 'अनेक', 'प्रकार', 
# ...

# %% [markdown]
# # NGRAMS

# %%
def CountFrequency(text):
    freq = {}
    for item in text:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1
    return freq

# %%
from nltk.util import ngrams

sentence = tran_hi_data
#unigram
uni = ngrams(sentence.split(), 1)
uni=list(uni)
dict_1=CountFrequency(uni)

#bigram
bi = ngrams(sentence.split(), 2)
bi=list(bi)
dict_2=CountFrequency(bi)

null1 = {}
for i in dict_1:
  t = i[0]
  null1[i[0]] = dict_1[i]

null2 = {}
for j in dict_2:
  t = j[0]
  null2[j[0]] = dict_2[j]
print("unigrams:")
print(dict_1)
print(len(dict_1))
print("\nbigrams:")
print(dict_2)
print(len(dict_2))
# Out:
# unigrams:
# ...

# %%
import pandas as pd
df1=pd.DataFrame(null1.items(),columns=['word','freq'])
df2=pd.DataFrame(null2.items(),columns=['word','freq'])
highdf=df1.nlargest(n=7, columns=['freq'])
highdf
# Out:
#    word  freq
# 26  में    26
# 33   को    24
# 9    के    23
# 37   से    19
# 42   और    18
# 82   की    17
# 3    का    15

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(highdf['word'],highdf['freq'])
plt.show()

# %% [markdown]
# # POS TAGGING

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# Raw Data

# %%
from collections import Counter
import nltk

tokenized = sent_tokenize(hindi_corpus)
for i in tokenized:
# Word tokenizers is used to find the words
    wordsList = nltk.word_tokenize(i)
 
# removing stop words from wordList
    wordsList = [w for w in wordsList if not w in stopwords]
 
    #  Using a Tagger we will find part-of-speech
    pos_tagged = nltk.pos_tag(wordsList)
 
    print(pos_tagged,end="\n")
# Out:
# [('मेरे', 'JJ'), ('मित्र', 'NNP'), ('रोहित', 'NNP'), ('जन्म-दिन', 'JJ'), ('था।', 'NNP'), ('उसने', 'NNP'), ('अन्य', 'NNP'), ('मित्रों', 'NNP'), ('मुझे', 'NNP'), ('बुलाया।', 'NNP'), ('रोहित', 'NNP'), ('रिश्तेदार', 'NNP'), ('आए', 'NNP'), (',', ','), ('किन्तु', 'NNP'), ('अधिकतर', 'NNP'), ('मित्र', 'NNP'), ('उपस्थित', 'NNP'), ('थे।', 'NNP'), ('आँगन', 'NNP'), ('समारोह', 'NNP'), ('आयोजन', 'NNP'), ('था।', 'NNP'), ('स्थान', 'NNP'), ('सुंदर', 'NNP'), ('ढंग', 'NNP'), ('सजाया', 'NNP'), ('था।', 'NNP'), ('हर', 'NNP'), ('जगह', 'NNP'), ('झण्डियाँ', 'NNP'), ('गुब्बारे', 'NNP'), ('थे।', 'NNP'), ('आँगन', 'NNP'), ('लगे', 'NNP'), ('पेड़', 'NNP'), ('रंग-बिरंगे', 'JJ'), ('बल्ब', 'NNP'), ('जगमग', 'NNP'), ('थे।', 'NNP'), ('मैं', 'NNP'), ('पहुँचा', 'NNP'), ('मेहमान', 'NNP'), ('आने', 'NNP'), ('शुरू', 'NNP'), ('थे।', 'NNP'), ('मेहमान', 'NNP'), ('रोहित', 'NNP'), ('कोई-न-कोई', 'JJ'), ('उपहार', 'NNP'), ('लेकर', 'NNP'), ('आते', 'NNP'), (',', ','), ('निकट', 'NNP'), ('जाकर', 'NNP'), ('बधाई', 'NNP'), ('देते', 'NNP'), 
# ...

# %%
d=dict()
a=[]
b=[]
for i,j in pos_tagged:
  if j not in d:
    d[j]=1
  else:
    d[j]+=1

# %%
for i in d:
  a.append(i)
  b.append(d[i])

# %%
plt.figure(1,figsize=(10,3))
plt.bar(a,b, color ='blue',
        width = 0.2)
plt.xlabel("Words count in dataframe")
plt.ylabel("Count")
plt.title("count of JJ,NNP,NN")
plt.savefig("count.png")
plt.show()

# %% [markdown]
# Filtered data

# %%
from collections import Counter
import nltk

tokenized = sent_tokenize(tran_hi_data)
for i in tokenized:
    wordsList = nltk.word_tokenize(i)
    wordsList = final_list
    pos_tagged_final = nltk.pos_tag(wordsList)
 
print(pos_tagged_final)
print(len(pos_tagged_final))
# Out:
# [('मेरे', 'JJ'), ('मित्र', 'NNP'), ('रोहित', 'NNP'), ('जन्मदिन', 'NNP'), ('था।', 'NNP'), ('उसने', 'NNP'), ('अन्य', 'NNP'), ('मित्रों', 'NNP'), ('मुझे', 'NNP'), ('बुलाया।', 'NNP'), ('रोहित', 'NNP'), ('रिश्तेदार', 'NNP'), ('आए', 'NNP'), ('किन्तु', 'NNP'), ('अधिकतर', 'NNP'), ('मित्र', 'NNP'), ('उपस्थित', 'NNP'), ('थे।', 'NNP'), ('आँगन', 'NNP'), ('समारोह', 'NNP'), ('आयोजन', 'NNP'), ('था।', 'NNP'), ('स्थान', 'NNP'), ('सुंदर', 'NNP'), ('ढंग', 'NNP'), ('सजाया', 'NNP'), ('था।', 'NNP'), ('हर', 'NNP'), ('जगह', 'NNP'), ('झण्डियाँ', 'NNP'), ('गुब्बारे', 'NNP'), ('थे।', 'NNP'), ('आँगन', 'NNP'), ('लगे', 'NNP'), ('पेड़', 'NNP'), ('रंगबिरंगे', 'NNP'), ('बल्ब', 'NNP'), ('जगमग', 'NNP'), ('थे।', 'NNP'), ('मैं', 'NNP'), ('पहुँचा', 'NNP'), ('मेहमान', 'NNP'), ('आने', 'NNP'), ('शुरू', 'NNP'), ('थे।', 'NNP'), ('मेहमान', 'NNP'), ('रोहित', 'NNP'), ('कोईनकोई', 'NNP'), ('उपहार', 'NNP'), ('लेकर', 'NNP'), ('आते', 'NNP'), ('निकट', 'NNP'), ('जाकर', 'NNP'), ('बधाई', 'NNP'), ('देते', 'NNP'), ('रोहित', 'NNP'), ('धन्यव
# ...

# %%
d1=dict()
a1=[]
b1=[]
for i,j in pos_tagged_final:
  if j not in d1:
    d1[j]=1
  else:
    d1[j]+=1

# %%
for i in d1:
  a1.append(i)
  b1.append(d1[i])

# %%
plt.figure(1,figsize=(10,3))
plt.bar(a1,b1, color ='blue',
        width = 0.2)
plt.xlabel("Words count in dataframe")
plt.ylabel("Count")
plt.title("count of JJ,NNP,NN")
plt.show()

# %% [markdown]
# ----------->

# %%
pip install stanfordnlp

# %% [markdown]
# ## ***Dependency parser***

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
for token in nlp(hindi_corpus):
   print(token.text,'=›',token.dep_,'=>',token.head.text)
# Out:
# मेरे =› ROOT => मेरे
# मित्र =› nummod => मेरे
# रोहित =› nmod => का
# का =› dep => जन्म
# जन्म =› compound => दिन
# - =› punct => दिन
# दिन =› amod => ।
# था =› compound => ।
# । =› cc => मेरे
# उसने =› compound => अन्य
# अन्य =› ROOT => अन्य
# मित्रों =› ROOT => मित्रों
# के =› dep => साथ
# साथ =› intj => मित्रों
# मुझे =› dep => भी
# भी =› punct => साथ
# बुलाया =› ROOT => बुलाया
# । =› ROOT => ।
# रोहित =› ROOT => रोहित
# के =› dep => कुछ
# कुछ =› compound => रिश्तेदार
# रिश्तेदार =› ROOT => रिश्तेदार
# भी =› punct => आए
# आए =› nmod => हुए
# हुए =› ROOT => हुए
# थे =› dep => ,
# , =› ROOT => ,
# किन्तु =› ROOT => किन्तु
# अधिकतर =› ROOT => अधिकतर
# मित्र =› punct => अधिकतर
# ही =› compound => उपस्थित
# उपस्थित =› ROOT => उपस्थित
# थे =› nmod => ।
# । =› punct => उपस्थित
# घर =› punct => उपस्थित
# के =› compound => आँगन
# आँगन =› ROOT => आँगन
# में =› punct => आँगन
# ही =› nummod => आँगन
# समारोह =› compound => का
# का =› ROOT => का
# आयोजन =› ROOT => आयोजन
# ...

# %%
from spacy import displacy 
displacy.render(nlp(hindi_corpus),jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="405089bb8173481cb96eebdea95325a0-0" class="displacy" width="168400" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">मेरे</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">मित्र</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
# ...

# %% [markdown]
# ## ***HMM***

# %%
# !pip install pomegranate

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict, namedtuple, OrderedDict
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution
import os
from io import BytesIO
from itertools import chain
import random

# %% [markdown]
# # ***NAMED-ENTITY REGONIZATION***

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
ne_tree = ne_chunk(pos_tag(word_tokenize(hindi_corpus)))

# %%
print(ne_tree)
# Out:
# (S
#   मेरे/JJ
#   मित्र/NNP
#   रोहित/NNP
#   का/NNP
#   जन्म-दिन/JJ
#   था।/NNP
#   उसने/NNP
#   अन्य/NNP
#   मित्रों/NNP
#   के/NNP
#   साथ/NNP
#   मुझे/NNP
#   भी/NNP
#   बुलाया।/NNP
#   रोहित/NNP
#   के/NNP
#   कुछ/NNP
#   रिश्तेदार/NNP
#   भी/NNP
#   आए/NNP
#   हुए/NNP
#   थे/NNP
#   ,/,
#   किन्तु/NNP
#   अधिकतर/NNP
#   मित्र/NNP
#   ही/NNP
#   उपस्थित/NNP
#   थे।/NNP
#   घर/NNP
#   के/NNP
#   आँगन/NNP
#   में/NNP
#   ही/NNP
#   समारोह/NNP
#   का/NNP
#   आयोजन/NNP
#   किया/NNP
#   गया/NNP
#   था।/NNP
#   उस/NNP
#   स्थान/NNP
#   को/NNP
#   बहुत/NNP
#   ही/NNP
#   सुंदर/NNP
#   ढंग/NNP
#   से/NNP
#   सजाया/NNP
#   गया/NNP
#   था।/NNP
#   हर/NNP
#   जगह/NNP
#   झण्डियाँ/NNP
#   और/NNP
#   गुब्बारे/NNP
#   थे।/NNP
#   आँगन/NNP
#   में/NNP
#   लगे/NNP
#   एक/NNP
#   पेड़/NNP
#   पर/NNP
#   रंग-बिरंगे/JJ
#   बल्ब/NNP
#   जगमग/NNP
#   कर/NNP
#   रहे/NNP
#   थे।/NNP
#   जब/NNP
#   मैं/NNP
#   पहुँचा/NNP
#   तो/NNP
#   मेहमान/NNP
#   आने/NNP
#   शुरू/NNP
#   ही/NNP
#   हुए/NNP
# ...

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(hindi_corpus)
sent
# Out:
# [('मेरे', 'JJ'),
#  ('मित्र', 'NNP'),
#  ('रोहित', 'NNP'),
#  ('का', 'NNP'),
#  ('जन्म-दिन', 'JJ'),
#  ('था।', 'NNP'),
#  ('उसने', 'NNP'),
#  ('अन्य', 'NNP'),
#  ('मित्रों', 'NNP'),
#  ('के', 'NNP'),
#  ('साथ', 'NNP'),
#  ('मुझे', 'NNP'),
#  ('भी', 'NNP'),
#  ('बुलाया।', 'NNP'),
#  ('रोहित', 'NNP'),
#  ('के', 'NNP'),
#  ('कुछ', 'NNP'),
#  ('रिश्तेदार', 'NNP'),
#  ('भी', 'NNP'),
#  ('आए', 'NNP'),
#  ('हुए', 'NNP'),
#  ('थे', 'NNP'),
#  (',', ','),
#  ('किन्तु', 'NNP'),
#  ('अधिकतर', 'NNP'),
#  ('मित्र', 'NNP'),
#  ('ही', 'NNP'),
#  ('उपस्थित', 'NNP'),
#  ('थे।', 'NNP'),
#  ('घर', 'NNP'),
#  ('के', 'NNP'),
#  ('आँगन', 'NNP'),
#  ('में', 'NNP'),
#  ('ही', 'NNP'),
#  ('समारोह', 'NNP'),
#  ('का', 'NNP'),
#  ('आयोजन', 'NNP'),
#  ('किया', 'NNP'),
#  ('गया', 'NNP'),
#  ('था।', 'NNP'),
#  ('उस', 'NNP'),
#  ('स्थान', 'NNP'),
#  ('को', 'NNP'),
#  ('बहुत', 'NNP'),
#  ('ही', 'NNP'),
#  ('सुंदर', 'NNP'),
#  ('ढंग', 'NNP'),
#  ('से', 'NNP'),
#  ('सजाया', 'NNP'),
#  ('गया', 'NNP'),
# ...

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'

# %%
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   मेरे/JJ
#   मित्र/NNP
#   रोहित/NNP
#   का/NNP
#   जन्म-दिन/JJ
#   था।/NNP
#   उसने/NNP
#   अन्य/NNP
#   मित्रों/NNP
#   के/NNP
#   साथ/NNP
#   मुझे/NNP
#   भी/NNP
#   बुलाया।/NNP
#   रोहित/NNP
#   के/NNP
#   कुछ/NNP
#   रिश्तेदार/NNP
#   भी/NNP
#   आए/NNP
#   हुए/NNP
#   थे/NNP
#   ,/,
#   किन्तु/NNP
#   अधिकतर/NNP
#   मित्र/NNP
#   ही/NNP
#   उपस्थित/NNP
#   थे।/NNP
#   घर/NNP
#   के/NNP
#   आँगन/NNP
#   में/NNP
#   ही/NNP
#   समारोह/NNP
#   का/NNP
#   आयोजन/NNP
#   किया/NNP
#   गया/NNP
#   था।/NNP
#   उस/NNP
#   स्थान/NNP
#   को/NNP
#   बहुत/NNP
#   ही/NNP
#   सुंदर/NNP
#   ढंग/NNP
#   से/NNP
#   सजाया/NNP
#   गया/NNP
#   था।/NNP
#   हर/NNP
#   जगह/NNP
#   झण्डियाँ/NNP
#   और/NNP
#   गुब्बारे/NNP
#   थे।/NNP
#   आँगन/NNP
#   में/NNP
#   लगे/NNP
#   एक/NNP
#   पेड़/NNP
#   पर/NNP
#   रंग-बिरंगे/JJ
#   बल्ब/NNP
#   जगमग/NNP
#   कर/NNP
#   रहे/NNP
#   थे।/NNP
#   जब/NNP
#   मैं/NNP
#   पहुँचा/NNP
#   तो/NNP
#   मेहमान/NNP
#   आने/NNP
#   शुरू/NNP
#   ही/NNP
#   हुए/NNP
# ...

# %%
NPChunker = nltk.RegexpParser(pattern) 
result = NPChunker.parse(sent)
#result.draw()

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint

iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('मेरे', 'JJ', 'O'),
#  ('मित्र', 'NNP', 'O'),
#  ('रोहित', 'NNP', 'O'),
#  ('का', 'NNP', 'O'),
#  ('जन्म-दिन', 'JJ', 'O'),
#  ('था।', 'NNP', 'O'),
#  ('उसने', 'NNP', 'O'),
#  ('अन्य', 'NNP', 'O'),
#  ('मित्रों', 'NNP', 'O'),
#  ('के', 'NNP', 'O'),
#  ('साथ', 'NNP', 'O'),
#  ('मुझे', 'NNP', 'O'),
#  ('भी', 'NNP', 'O'),
#  ('बुलाया।', 'NNP', 'O'),
#  ('रोहित', 'NNP', 'O'),
#  ('के', 'NNP', 'O'),
#  ('कुछ', 'NNP', 'O'),
#  ('रिश्तेदार', 'NNP', 'O'),
#  ('भी', 'NNP', 'O'),
#  ('आए', 'NNP', 'O'),
#  ('हुए', 'NNP', 'O'),
#  ('थे', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('किन्तु', 'NNP', 'O'),
#  ('अधिकतर', 'NNP', 'O'),
#  ('मित्र', 'NNP', 'O'),
#  ('ही', 'NNP', 'O'),
#  ('उपस्थित', 'NNP', 'O'),
#  ('थे।', 'NNP', 'O'),
#  ('घर', 'NNP', 'O'),
#  ('के', 'NNP', 'O'),
#  ('आँगन', 'NNP', 'O'),
#  ('में', 'NNP', 'O'),
#  ('ही', 'NNP', 'O'),
#  ('समारोह', 'NNP', 'O'),
#  ('का', 'NNP', 'O'),
#  ('आयोजन', 'NNP', 'O'),
#  ('किया', 'NNP', 'O'),
#  ('गया', 'NNP', 'O'),
#  ('था।', 'NNP', 'O'),
# ...

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc=nlp(hindi_corpus)
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('सजाया', 'CARDINAL'),
#  ('।', 'CARDINAL'),
#  ('।', 'PRODUCT'),
#  ('उपहार लेकर आते', 'FAC'),
#  ('उनका', 'PERSON'),
#  ('। संगीत', 'PRODUCT'),
#  ('मधुर', 'PRODUCT'),
#  ('।', 'PRODUCT'),
#  ('लोगों', 'CARDINAL'),
#  ('मिठाइयाँ', 'PRODUCT'),
#  ('दीर्घायु', 'PRODUCT'),
#  ('कामना', 'PRODUCT'),
#  ('इतना', 'CARDINAL'),
#  ('पृथ्वी', 'CARDINAL'),
#  ('पृथ्वी को', 'PRODUCT'),
#  ('नष्ट', 'PRODUCT'),
#  ('पृथ्वी', 'PRODUCT'),
#  ('गर्म', 'PRODUCT'),
#  ('।', 'PRODUCT'),
#  ('गैसें', 'PRODUCT'),
#  ('को वायुमंडल', 'PRODUCT'),
#  ('देती', 'PRODUCT'),
#  ('कहा', 'DATE'),
#  ('है', 'GPE'),
#  ('है', 'PERSON'),
#  ('।', 'PRODUCT'),
#  ('संतुलन', 'GPE'),
#  ('कृषि को भी', 'PRODUCT'),
#  ('परिस्थितियों', 'ORG'),
#  ('ग्लेशियरों', 'DATE'),
#  ('बर्फ़बारी', 'PRODUCT'),
#  ('घटनाओं', 'PRODUCT'),
#  ('है', 'ORG'),
#  ('।', 'PRODUCT'),
#  ('है', 'PERSON'),
#  ('है', 'PERSON'),
#  ('करे', 'PERSON'),
#  ('हो। पेपर', 'ORG'),
#  ('चाहिए', 'PRODUCT'),
#  ('को लोगों', 'GPE'),
# ...

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(मेरे, 'O', ''),
#  (मित्र, 'O', ''),
#  (रोहित, 'O', ''),
#  (का, 'O', ''),
#  (जन्म, 'O', ''),
#  (-, 'O', ''),
#  (दिन, 'O', ''),
#  (था, 'O', ''),
#  (।, 'O', ''),
#  (उसने, 'O', ''),
#  (अन्य, 'O', ''),
#  (मित्रों, 'O', ''),
#  (के, 'O', ''),
#  (साथ, 'O', ''),
#  (मुझे, 'O', ''),
#  (भी, 'O', ''),
#  (बुलाया, 'O', ''),
#  (।, 'O', ''),
#  (रोहित, 'O', ''),
#  (के, 'O', ''),
#  (कुछ, 'O', ''),
#  (रिश्तेदार, 'O', ''),
#  (भी, 'O', ''),
#  (आए, 'O', ''),
#  (हुए, 'O', ''),
#  (थे, 'O', ''),
#  (,, 'O', ''),
#  (किन्तु, 'O', ''),
#  (अधिकतर, 'O', ''),
#  (मित्र, 'O', ''),
#  (ही, 'O', ''),
#  (उपस्थित, 'O', ''),
#  (थे, 'O', ''),
#  (।, 'O', ''),
#  (घर, 'O', ''),
#  (के, 'O', ''),
#  (आँगन, 'O', ''),
#  (में, 'O', ''),
#  (ही, 'O', ''),
#  (समारोह, 'O', ''),
#  (का, 'O', ''),
#  (आयोजन, 'O', ''),
#  (किया, 'O', ''),
#  (गया, 'O', ''),
#  (था, 'O', ''),
#  (।, 'O', ''),
#  (उस, 'O', ''),
#  (स्थान, 'O', ''),
#  (को, 'O', ''),
#  (बहुत, 'O', ''),
#  (ही, 'O', ''),
# ...

# %%
displacy.render(doc, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">मेरे मित्र रोहित का जन्म-दिन था। उसने अन्य मित्रों के साथ मुझे भी बुलाया। रोहित के कुछ रिश्तेदार भी आए हुए थे, किन्तु अधिकतर मित्र ही उपस्थित थे। घर के आँगन में ही समारोह का आयोजन किया गया था। उस स्थान को बहुत ही सुंदर ढंग से
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     सजाया
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  गया था। हर जगह झण्डियाँ और गुब्बारे थे
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ।
# ...

# %% [markdown]
# # ***Wordnet***

# %%
# !pip install spacy-wordnet

# %%
# !pip install scattertext

# %%
import pandas as pd
cols=("text","lemma","POS","explain","stopword")
rows=[]
for t in doc:
  row=[t.text,t.lemma_,t.pos_,spacy.explain(t.pos_),t.is_stop]
  rows.append(row)
df=pd.DataFrame(rows,columns=cols)
print(df)
# Out:
#        text  lemma    POS      explain  stopword
# 0      मेरे   मेरे  PROPN  proper noun     False
# 1     मित्र  मित्र   PART     particle     False
# 2     रोहित  रोहित   NOUN         noun     False
# 3        का     का   VERB         verb     False
# 4      जन्म   जन्म    ADJ    adjective     False
# ...     ...    ...    ...          ...       ...
# 1081     ही     ही  PROPN  proper noun     False
# 1082  जौहरी  जौहरी  PROPN  proper noun     False
# 1083  बाजार  बाजार   NOUN         noun     False
# 1084     था     था   NOUN         noun     False
# 1085      ।      ।  PUNCT  punctuation     False
#
# [1086 rows x 5 columns]

# %%
data=[]
for i in sent_tokenize(hindi_corpus):
  temp=[]
  for j in word_tokenize(i):
    temp.append(j.lower())
  data.append(temp)

# %% [markdown]
# # ***Summarization***

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from collections import Counter
from heapq import nlargest

# %%
with open('/content/corpus.txt') as fp:
	data = fp.read()

# %%
doc=nlp(data)
doc
# Out:
# मेरे मित्र रोहित का जन्म-दिन था। उसने अन्य मित्रों के साथ मुझे भी बुलाया। रोहित के कुछ रिश्तेदार भी आए हुए थे, किन्तु अधिकतर मित्र ही उपस्थित थे। घर के आँगन में ही समारोह का आयोजन किया गया था। उस स्थान को बहुत ही सुंदर ढंग से सजाया गया था। हर जगह झण्डियाँ और गुब्बारे थे। आँगन में लगे एक पेड़ पर रंग-बिरंगे बल्ब जगमग कर रहे थे। जब मैं पहुँचा तो मेहमान आने शुरू ही हुए थे। मेहमान रोहित के लिए कोई-न-कोई उपहार लेकर आते, उसके निकट जाकर बधाई देते और रोहित उनका धन्यवाद करता। क्रमशः लोग छोटी-छोटी टोलियों में बैठकर गपशप करने लगे। संगीत की मधुर ध्वनियाँ गूँज रही थी। एक-दो मित्र उठकर नृत्य करने लगे। कुछ मित्र तालियों बजा कर अपना योगदान देने लगे। चारों ओर उल्लास का वातावरण था। सात बजे के लगभग केक काटा गया। सब मित्रों ने तालियाँ बजाई और मिलकर जन्मदिन की बधाई का गीत गाया। माँ ने रोहित को केक खिलाया। अन्य लोगों ने भी केक खाया। फिर सभी खाना खाने लगे। खाने में अनेक प्रकार की मिठाइयाँ और नमकीन थे। तब हमने रोहित को एक बार फिर बधाई दी, उसकी दीर्घायु की कामना की और अपने-अपने घर को चल दिए। वह कार्यक्रम इतना
# ...

# %%
nlp = spacy.load("en_core_web_sm")

# %%
keyword = []
pos_tag = ['PROPN', 'ADJ', 'NOUN', 'VERB']
for token in doc:
    if(token.text in stopwords or token.text in punctuation):
        continue
    if(token.pos_ in pos_tag):
        keyword.append(token.text)

# %%
freq_word = Counter(keyword)
print(freq_word.most_common(3))
# Out:
# [('।', 28), ('रही', 8), ('वृद्धि', 8)]

# %%
type(freq_word)
# Out:
# collections.Counter

# %%
max_freq = Counter(keyword).most_common(1)[0][1]
for word in freq_word.keys():  
        freq_word[word] = (freq_word[word]/max_freq)
freq_word.most_common(5)
# Out:
# [('।', 0.0012755102040816326),
#  ('रही', 0.00036443148688046647),
#  ('वृद्धि', 0.00036443148688046647),
#  ('वर्षा', 0.00031887755102040814),
#  ('लगे', 0.00027332361516034986)]

# %%
sent_strength={}
for sent in doc.sents:
    for word in sent:
        if word.text in freq_word.keys():
            if sent in sent_strength.keys():
                sent_strength[sent]+=freq_word[word.text]
            else:
                sent_strength[sent]=freq_word[word.text]
print(sent_strength)
# Out:
# {मेरे मित्र रोहित का जन्म-दिन था।: 0.04464285714285714, उसने अन्य: 0.007653061224489796, मित्रों के साथ मुझे भी: 0.007653061224489796, बुलाया: 0.0012755102040816326, ।: 0.03571428571428571, रोहित: 0.0012755102040816326, के कुछ रिश्तेदार: 0.0012755102040816326, किन्तु: 0.002551020408163265, अधिकतर मित्र: 0.002551020408163265, ही उपस्थित थे। घर: 0.03571428571428571, के आँगन में ही: 0.0012755102040816326, समारोह का: 0.0012755102040816326, आयोजन: 0.0012755102040816326, था।: 0.03571428571428571, उस स्थान को बहुत ही सुंदर ढंग से सजाया गया: 0.00510204081632653, था।: 0.03571428571428571, हर जगह: 0.003826530612244898, झण्डियाँ और गुब्बारे थे। आँगन में लगे एक पेड़ पर: 0.04719387755102041, रंग-: 0.0012755102040816326, बिरंगे बल्ब जगमग कर रहे थे।: 0.03954081632653061, जब मैं पहुँचा: 0.00510204081632653, तो मेहमान आने शुरू ही: 0.006377551020408163, थे। मेहमान: 0.03826530612244898, रोहित: 0.0012755102040816326, लिए कोई-न-कोई उपहार लेकर आते, उसके निकट जाकर: 0.003826530612244898, बधाई देते: 0.002551
# ...

# %%
summarized_sentences = nlargest(3, sent_strength, key=sent_strength.get)
print(summarized_sentences)
# Out:
# [। क्रमशः लोग छोटी-छोटी टोलियों में बैठकर गपशप करने लगे। संगीत की, रही थी। मुझे वर्षा की, बचे हैं। जैसे-जैसे उद्योगों को संख्या बढ़ रही है, शहरीकरण हो रहा है, वाहनों की]

# %%
final_sentences = [ w.text for w in summarized_sentences ]
summary = ' '.join(final_sentences)
print(summary)
# Out:
# । क्रमशः लोग छोटी-छोटी टोलियों में बैठकर गपशप करने लगे। संगीत की रही थी। मुझे वर्षा की बचे हैं। जैसे-जैसे उद्योगों को संख्या बढ़ रही है, शहरीकरण हो रहा है, वाहनों की

# %%
len(summary)
# Out:
# 165
